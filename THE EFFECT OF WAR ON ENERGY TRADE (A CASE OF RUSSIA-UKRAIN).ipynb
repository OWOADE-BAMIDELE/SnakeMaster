# %%
import pandas as pd

# Manually extracted data from the image
data = {
    'Author(s)': [
        'Balsalobre-Lorente et al.', 'Adekoya et al.', 'Boungou and Yatié', 
        'Kayani et al.', 'Ahmed et al.', 'Chen et al.'
    ],
    'Year': [2023, 2023, 2022, 2024, 2022, 2023],
    'Methodology': [
        'Cross-Quantilogram, Partial Cross-Quantilogram', 'Multifractality, Cross-Correlation', 
        'Empirical Analysis', 'Diebold and Yilmaz Spillover Framework, E-GARCH', 
        'Event Study', 'Volatility Ratio Analysis'
    ],
    'Key Findings': [
        'Significant shocks in G7 oil and gas markets due to the war.',
        'War increased inefficiency in stock markets, especially in Europe.',
        'Negative impact on global stock markets.',
        'High spillovers in Brent oil; stability in natural gas.',
        'Negative abnormal returns in European stock markets.',
        'Significant volatility in natural gas market due to war.'
    ],
    'Observations': [
        'Highlights the vulnerability of energy-dependent economies.',
        'Emphasizes the interconnectedness of global markets.',
        'Broad economic consequences of geopolitical conflicts.',
        'Brent oil is highly susceptible to geopolitical risks.',
        'Stock markets are sensitive to geopolitical crises.',
        'Natural gas market is particularly volatile during crises.'
    ]
}

df = pd.DataFrame(data)

# %% [markdown]
# Theme 1: Market Dynamics and Volatility

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all key findings into one string
text_key_findings = " ".join(df['Key Findings'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_key_findings)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 1: Market Dynamics and Volatility (Word Cloud)")
plt.show()

# %%
# Combine all observations into one string
text_observations = " ".join(df['Observations'])

# Generate the word cloud (Tag Cloud)
tagcloud = WordCloud(width=800, height=400, background_color='white').generate(text_observations)

# Plot the tag cloud
plt.figure(figsize=(10, 5))
plt.imshow(tagcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 1: Market Dynamics and Volatility (Tag Cloud for Observations)")
plt.show()

# %%
import seaborn as sns

# Counting occurrences per author
author_year_counts = df.groupby(['Year', 'Author(s)']).size().reset_index(name='Counts')

# Generate the bubble chart
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=author_year_counts, x='Year', y='Author(s)', 
    size='Counts', hue='Counts', sizes=(100, 1000), palette='viridis', legend=False
)

plt.title("Theme 1: Market Dynamics and Volatility (Bubble Chart of Authors vs Year)")
plt.xlabel("Year")
plt.ylabel("Author(s)")
plt.show()

# %% [markdown]
# Theme 2: Geopolitical and Policy Implications

# %%
# Data from the image
data_theme_2 = {
    'Author(s)': [
        'Kuzemko et al.', 'Osíčka and', 'Goldthau and', 
        'Luschini et al.', 'Xin and Ming', 'Chishti et al.'
    ],
    'Year': [2022, 2022, 2014, 2024, 2023, 2023],
    'Methodology': [
        'Policy Analysis', 'Paradigm Shift Analysis', 
        'Policy Analysis', 'Comparative Analysis', 
        'Evolutionary Game Theory', 'Cross-Quantilogram, RWMC'
    ],
    'Key Findings': [
        'Shift towards clean energy and reconsideration of energy equity.',
        'Increased role of the state in energy policy; push for decarbonization.',
        'Persistent gaps between policy and market realities.',
        'Altered energy strategies in Germany and the UK due to the crisis.',
        'Sanctions on Russia had varied impacts; non-sanctioning countries benefit.',
        'Asymmetric effects on energy, metals, and agriculture; need for diversification.'
    ],
    'Observations': [
        'Highlights the need for sustainable energy policies.',
        'Suggests a long-term shift in European energy politics.',
        'Historical insights reveal ongoing policy challenges.',
        'Countries are forced to rapidly adapt energy policies.',
        'Diplomatic efforts are crucial to stabilizing energy trade.',
        'Diversification is key to mitigating geopolitical risks.'
    ]
}

df_theme_2 = pd.DataFrame(data_theme_2)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all key findings into one string
text_key_findings = " ".join(df_theme_2['Key Findings'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_key_findings)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 2: Geopolitical and Policy Implications (Word Cloud for Key Findings)")
plt.show()

# %%
# Combine all observations into one string
text_observations = " ".join(df_theme_2['Observations'])

# Generate the word cloud (Tag Cloud)
tagcloud = WordCloud(width=800, height=400, background_color='white').generate(text_observations)

# Plot the tag cloud
plt.figure(figsize=(10, 5))
plt.imshow(tagcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 2: Geopolitical and Policy Implications (Tag Cloud for Observations)")
plt.show()

# %%
import seaborn as sns

# Counting occurrences per author
author_year_counts = df_theme_2.groupby(['Year', 'Author(s)']).size().reset_index(name='Counts')

# Generate the bubble chart
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=author_year_counts, x='Year', y='Author(s)', 
    size='Counts', hue='Counts', sizes=(100, 1000), palette='viridis', legend=False
)

plt.title("Theme 2: Geopolitical and Policy Implications (Bubble Chart of Authors vs Year)")
plt.xlabel("Year")
plt.ylabel("Author(s)")
plt.show()

# %% [markdown]
# Theme 3: Energy Security and Sustainability

# %%
data_theme_3 = {  
    'Author(s)': ['Kuzemko et al.', 'Osička and Černoch', 'Goldthau and Boersma', 'Chen et al.', 'Luschini et al.', 'Kayani et al.'],  
    'Year': [2022, 2022, 2014, 2023, 2024, 2024],  
    'Methodology': ['Policy Analysis', 'Paradigm Shift Analysis', 'Policy Analysis', 'Volatility Ratio Analysis', 'Comparative Analysis', 'Diebold and Yilmaz Spillover'],  
    'Key Findings': ['Need for resilient and sustainable energy systems in Europe.', 'European energy security strategies must adapt to new geopolitical realities.', 'Challenges of aligning energy security with market realities.', 'Importance of diversifying energy sources to ensure stability.', 'Reassessment of energy security strategies in Germany and the UK.', 'Volatility in energy markets underscores need for robust security measures.'],  
    'Observations': ['War highlights vulnerabilities in current energy security strategies.', 'Energy security is increasingly tied to sustainability goals.', 'Historical lessons are crucial for future energy policies.', 'Energy diversification is key to enhancing security.', 'Crisis forces countries to reconsider energy dependencies.', 'Energy market volatility highlights the fragility of current systems.']  
}  

df_theme_3 = pd.DataFrame(data_theme_3)

# %%
# Combine all key findings into one string
text_key_findings = " ".join(df_theme_3['Key Findings'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_key_findings)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 3: Energy Security and Sustainability (Word Cloud for Key Findings)")
plt.show()

# %%
text_observations = " ".join(df_theme_3['Observations'])

# Generate the word cloud (Tag Cloud)
tagcloud = WordCloud(width=800, height=400, background_color='white').generate(text_observations)

# Plot the tag cloud
plt.figure(figsize=(10, 5))
plt.imshow(tagcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Theme 3: Energy Security and Sustainability (Tag Cloud for Observations)")
plt.show()

# %%
# Counting occurrences per author
author_year_counts = df_theme_3.groupby(['Year', 'Author(s)']).size().reset_index(name='Counts')

# Generate the bubble chart
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=author_year_counts, x='Year', y='Author(s)', 
    size='Counts', hue='Counts', sizes=(100, 1000), palette='viridis', legend=False
)

plt.title("Theme 3: Energy Security and Sustainability (Bubble Chart of Authors vs Year)")
plt.xlabel("Year")
plt.ylabel("Author(s)")
plt.show()
