# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import the datset into python
df = pd.read_excel(r"C:\Users\ia\Desktop\Travail\Oloye Olarenwaju\1\FIKA Research Data.xlsx")

# %%
# View the first five variables
df.head()
# Out:
#   PARTICIPANT researcher  gender  age baseline date follow up date  \
# 0       10UJW       Ayan    male  18+    2024-04-01     2024-04-14
# 1       12DUR       Ayan  female  18+    2024-04-03     2024-04-17
# 2       11SHA       Ayan    male  18+    2024-04-15     2024-04-29
# 3       12SHA       Ayan    male  18+    2024-05-03     2024-05-17
# 4       09JAY       Ayan    male  18+    2024-05-04     2024-05-18
#
#    GAD7 ( SCORE)Pre experiment group  GAD7 (SCORE) Post  \
# 0                 4             FIKA                5.0
# 1                 5             FIKA                6.0
# 2                15             FIKA                4.0
# 3                11         waitlist                8.0
# 4                 8         waitlist                5.0
#
#                                 Useful parts of FIKA  \
# 0  Imagining about the good moment and feeling wi...
# 1               The overall activities and exercises
# 2                                       Accessiblity
# ...

# %%
# View the last five variables
df.tail()
# Out:
#    PARTICIPANT researcher  gender  age baseline date follow up date  \
# 55       06CHE       Idil  female  18+    2024-07-26     2024-08-06
# 56       06KEY       Idil    male  18+    2024-07-23     2024-08-06
# 57       10GUL       Idil  female  18+    2024-07-24     2024-08-03
# 58       10BAH       Idil    male  18+    2024-07-24     2024-08-03
# 59       03HAN       Idil    male  18+    2024-07-24     2024-08-07
#
#     GAD7 ( SCORE)Pre experiment group  GAD7 (SCORE) Post  \
# 55                20             FIKA                3.0
# 56                 9         waitlist                5.0
# 57                 6             FIKA                3.0
# 58                12             FIKA                7.0
# 59                 2         waitlist                3.0
#
#                                  Useful parts of FIKA  \
# 55  The mini movie and the imagery to manage my an...
# 56                                                NaN
# ...

# %%
# Convert categorical variables to numerical
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})
df['experiment group'] = df['experiment group'].map({'FIKA': 0, 'Waitlist': 1})

# %%
# Descriptive statistics for numerical variables
print(df[['GAD7 (SCORE)Pre', 'GAD7(SCORE)Post', 'gender', 'experiment group']].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Descriptive statistics for numerical variables
# ----> 2 print(df[['GAD7 (SCORE)Pre', 'GAD7(SCORE)Post', 'gender', 'experiment group']].describe())
#
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
# Read the data from the image  
data = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'female', 'male', 'female', 'female', 'male', 'female', 'male', 'female', 'female', 'male', 'male', 'male'],  
        'age': ['18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+', '18+'],  
        'baseline date': ['01-04-2024', '03-04-2024', '15-04-2024', '03-05-2024', '04-05-2024', '05-05-2024', '15-05-2024', '01-06-2024', '06-06-2024', '11-06-2024', '09-06-2024', '15-06-2024', '17-06-2024', '01-07-2024', '27-05-2024', '23-05-2024', '25-05-2024', '14-06-2024', '28-06-2024', '25-05-2024', '25-05-2024', '27-05-2024', '01-07-2024', '28-06-2024', '21-06-2024', '26-05-2024', '27-06-2024', '25-05-2024', '02-07-2024', '03-07-2024', '15-07-2024', '18-07-2024', '16-07-2024', '18-07-2024', '24-07-2024', '26-07-2024', '23-07-2024', '13-07-2024', '17-07-2024', '24-07-2024', '18-08-2024', '26-07-2024', '27-07-2024', '17-07-2024', '17-07-2024', '24-07-2024', '26-07-2024', '18-07-2024', '24-07-2024', '18-07-2024', '24-07-2024', '26-07-2024', '23-07-2024', '26-07-2024', '19-07-2024', '26-07-2024', '23-07-2024', '24-07-2024', '24-07-2024', '24-07-2024'],  
        'follow up date': ['14-04-2024', '17-04-2024', '29-04-2024', '17-05-2024', '18-05-2024', '19-05-2024', '29-05-2024', '15-06-2024', '20-06-2024', '25-06-2024', '23-06-2024', '29-06-2024', '01-07-2024', '15-07-2024', '10-06-2024', '06-06-2024', '09-06-2024', '30-06-2024', '14-07-2024', '17-06-2024', '09-06-2024', '10-06-2024', '14-07-2024', '14-07-2024', '07-07-2024', '09-06-2024', '14-07-2024', '08-07-2024', '14-07-2024', '14-07-2024', '29-07-2024', '30-07-2024', '29-07-2024', '01-08-2024', '05-08-2024', '06-08-2024', '05-08-2024', '28-07-2024', '01-08-2024', '05-08-2024', '01-08-2024', '05-08-2024', '10-08-2024', '01-08-2024', '31-07-2024', '05-08-2024', '11-08-2024', '01-08-2024', '05-08-2024', '01-08-2024', '07-08-2024', '06-08-2024', '06-08-2024', '10-08-2024', '02-08-2024', '06-08-2024', '03-08-2024', '03-08-2024', '07-08-2024'],  
        'GAD7 (SCORE)Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 20, 9, 6, 12, 2],  
        'experiment group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA'],  
        'GAD7 (SCORE) Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 13, 8, 15, 5, 11, 3, 6, 12, 13, 12, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 2, 14, 2, 7, 2, 3, 9, 3, 3, 5, 3, 7, 3]}  

# Create a Pandas DataFrame from the data  
df = pd.DataFrame(data)  

# Convert the gender column to numerical data  
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'male' else 0)  

# Print the descriptive statistics of the selected variables  
print(df[['gender', 'GAD7 (SCORE)Pre', 'GAD7 (SCORE) Post', 'experiment group']].describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 11
#       2 data = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'female', 'male', 'female', 'female', 'male', 'female', 'male', 'female', 'female', 'male', 'male', 'male'],
# ...

# %%
from scipy import stats

# %%
# Create a DataFrame from the data  
data2 = {  
    'baseline date': ['01-04-2024', '03-04-2024', '15-04-2024', '03-05-2024', '04-05-2024', '05-05-2024', '15-05-2024', '01-06-2024', '06-06-2024', '11-06-2024', '09-06-2024', '15-06-2024', '17-06-2024', '01-07-2024', '27-05-2024', '23-05-2024', '25-05-2024', '14-06-2024', '28-06-2024', '25-05-2024', '25-05-2024', '27-05-2024', '28-06-2024', '21-06-2024', '26-05-2024', '27-06-2024', '25-05-2024', '02-07-2024', '03-07-2024', '15-07-2024', '18-07-2024', '16-07-2024', '18-07-2024', '24-07-2024', '26-07-2024', '23-07-2024', '13-07-2024', '17-07-2024', '24-07-2024', '18-08-2024', '26-07-2024', '27-07-2024', '17-07-2024', '17-07-2024', '24-07-2024', '26-07-2024', '18-07-2024', '24-07-2024', '18-07-2024', '24-07-2024', '26-07-2024', '23-07-2024', '26-07-2024', '19-07-2024', '26-07-2024', '23-07-2024', '24-07-2024', '24-07-2024', '24-07-2024'],  
    'follow up date': ['14-04-2024', '17-04-2024', '29-04-2024', '17-05-2024', '18-05-2024', '19-05-2024', '29-05-2024', '15-06-2024', '20-06-2024', '25-06-2024', '23-06-2024', '29-06-2024', '01-07-2024', '15-07-2024', '10-06-2024', '06-06-2024', '09-06-2024', '30-06-2024', '14-07-2024', '17-06-2024', '09-06-2024', '01-07-2024', '14-07-2024', '07-07-2024', '09-06-2024', '14-07-2024', '08-07-2024', '14-07-2024', '14-07-2024', '29-07-2024', '30-07-2024', '29-07-2024', '01-08-2024', '05-08-2024', '06-08-2024', '05-08-2024', '28-07-2024', '01-08-2024', '05-08-2024', '01-08-2024', '05-08-2024', '10-08-2024', '01-08-2024', '31-07-2024', '05-08-2024', '11-08-2024', '01-08-2024', '05-08-2024', '01-08-2024', '07-08-2024', '06-08-2024', '06-08-2024', '10-08-2024', '02-08-2024', '06-08-2024', '06-08-2024', '03-08-2024', '03-08-2024', '07-08-2024'],  
    'GAD7 (SCORE)Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 14, 13, 10, 14, 13, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 20, 9, 6, 12, 2],  
    'experiment group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA'],  
}

# %%
# Create a Pandas DataFrame from the data  
df2 = pd.DataFrame(data2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Create a Pandas DataFrame from the data
# ----> 2 df2 = pd.DataFrame(data2)
#
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
# Filter data for each group  
FIKA_group = df2[df2['experiment group'] == 'FIKA']['GAD7 (SCORE)Pre']  
waitlist_group = df2[d2f['experiment group'] == 'waitlist']['GAD7 (SCORE)Pre']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Filter data for each group
# ----> 2 FIKA_group = df2[df2['experiment group'] == 'FIKA']['GAD7 (SCORE)Pre']
#       3 waitlist_group = df2[d2f['experiment group'] == 'waitlist']['GAD7 (SCORE)Pre']
#
# NameError: name 'df2' is not defined

# %%
# Perform a two-sample t-test  
t_statistic, p_value = stats.ttest_ind(FIKA_group, waitlist_group)

# %%
# Print the results  
print(f"T-statistic: {t_statistic:.4f}")  
print(f"P-value: {p_value:.4f}")

# %%
# Interpretation  
if p_value < 0.05:  
    print("There is a statistically significant difference in baseline GAD7 scores between the FIKA and waitlist groups.")  
else:  
    print("There is no statistically significant difference in baseline GAD7 scores between the FIKA and waitlist groups.")

# %%
import statsmodels.formula.api as sm

# %%
# Create a DataFrame from the data  
data3 = {  
    'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'female', 'male', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'male'],  
    'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA'],  
    'GAD7_Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 12, 15, 14, 11, 14, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 6, 20, 9, 6, 12, 2],  
    'GAD7_Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 8, 15, 5, 11, 3, 6, 12, 13, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 14, 2, 7, 2, 3, 9, 3, 3, 3, 5, 3, 7, 3]  
}

# %%
df3 = pd.DataFrame(data3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df3 = pd.DataFrame(data3)
#
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
# ...

# %%
# Convert gender to a numerical variable  
df['gender'] = df['gender'].map({'male': 1, 'female': 2})

# %%
# Perform the repeated measures ANOVA  
model = sm.mixedlm('GAD7_Post ~ gender + experiment_group', data=df, re_formula='~1', groups='gender')  
results = model.fit()

# %%
# Print the results  
print(results.summary())

# %%
# Get the means, standard errors, and confidence intervals  
means = results.params  
se = results.bse  
lower = means - 1.96 * se  
upper = means + 1.96 * se

# %%
# Create a table of the results  
results_table = pd.DataFrame({'Means': means, 'S.E': se, 'Lower': lower, 'Upper': upper})  
print(results_table)

# %%
# Create a figure with multiple subplots  
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# %%
# Create a bar plot for the means of the GAD7 (SCORE) Post by experiment group  
sns.barplot(x='experiment_group', y='GAD7_Post', data=df, ax=ax[0])  
ax[0].set_title('Means of GAD7 (SCORE) Post by Experiment Group')  
ax[0].set_xlabel('Experiment Group')  
ax[0].set_ylabel('GAD7 (SCORE) Post')

# %%
# Create a bar plot for the means of the GAD7 (SCORE) Post by gender  
sns.barplot(x='gender', y='GAD7_Post', data=df, ax=ax[1])  
ax[1].set_title('Means of GAD7 (SCORE) Post by Gender')  
ax[1].set_xlabel('Gender')  
ax[1].set_ylabel('GAD7 (SCORE) Post')

# %%
# Show the plot  
plt.tight_layout()  
plt.show()

# %%
import statsmodels.formula.api as sm

# %%
# Create a DataFrame from the data  
data4 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'female', 'male', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'female', 'male', 'male'],  
        'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist'],  
        'GAD7_SCORE_Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 6, 20, 9, 6, 12, 2],  
        'GAD7_SCORE_Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 13, 8, 15, 5, 11, 3, 6, 12, 13, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 14, 2, 7, 2, 3, 9, 3, 3, 5, 3, 3, 7, 3]}  

df4 = pd.DataFrame(data4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 7
#       1 # Create a DataFrame from the data
#       2 data4 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'female', 'female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'female', 'male', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'female', 'male', 'male'],
# ...

# %%
# Create a formula for the repeated measures ANOVA  
formula = 'GAD7_SCORE_Post ~ gender + experiment_group + gender:experiment_group'

# %%
# Fit the model  
model = sm.ols(formula, data=df)  
results = model.fit()

# %%
# Print the results  
print(results.summary())

# %%
# Boxplot of GAD7_SCORE_Post by gender and exp_group  
plt.figure(figsize=(10,6))  
sns.boxplot(x='experiment_group', y='GAD7_SCORE_Post', hue='gender', data=df)  
plt.title('GAD7_SCORE_Post by Gender and Experiment Group')  
plt.show()

# %%
# Barplot of mean GAD7_SCORE_Post by gender and exp_group  
plt.figure(figsize=(10,6))  
sns.barplot(x='experiment_group', y='GAD7_SCORE_Post', hue='gender', data=df)  
plt.title('Mean GAD7_SCORE_Post by Gender and Experiment Group')  
plt.show()

# %%
# Interaction plot of GAD7_SCORE_Post by gender and exp_group  
from statsmodels.graphics.factorplots import interaction_plot  
plt.figure(figsize=(10,6))  
interaction_plot(df['gender'], df['experiment_group'], response=df['GAD7_SCORE_Post'])  
plt.title('Interaction Plot of GAD7_SCORE_Post by Gender and Experiment Group')  
plt.show()

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Sample data (60 rows)  
np.random.seed(0)  
data5 = pd.DataFrame({  
    'Experiment Group': np.random.choice(['FIKA', 'waitlist'], size=60),  
    'GAD7 Score (Pre)': np.random.normal(10, 5, size=60)  
})

# %%
# Density plot  
plt.figure(figsize=(8,6))  
sns.kdeplot(data5[data5['Experiment Group'] == 'FIKA']['GAD7 Score (Pre)'], label='FIKA')  
sns.kdeplot(data5[data5['Experiment Group'] == 'waitlist']['GAD7 Score (Pre)'], label='waitlist')  
plt.xlabel('GAD7 Score (Pre)')  
plt.ylabel('Density')  
plt.title('Density Map of GAD7 Score (Pre) by Experiment Group')  
plt.legend()  
plt.show()

# %%
# Sample data (60 rows)  
np.random.seed(0)  
data = pd.DataFrame({  
    'Experiment Group': np.random.choice(['FIKA', 'waitlist'], size=60),  
    'GAD7 Score (Pre)': np.random.normal(10, 5, size=60)  
})

# %%
# Density plot  
plt.figure(figsize=(8,6))  
sns.kdeplot(data[data['Experiment Group'] == 'FIKA']['GAD7 Score (Pre)'], label='FIKA')  
sns.kdeplot(data[data['Experiment Group'] == 'waitlist']['GAD7 Score (Pre)'], label='waitlist')  
plt.xlabel('GAD7 Score (Pre)')  
plt.ylabel('Density')  
plt.title('Density Map of GAD7 Score (Pre) by Experiment Group')  
plt.legend()  
plt.show()

# %%
# Create the dataset  
data6 = {  
    'GAD7 (SCORE)Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 6, 20, 9, 6, 12, 2],  
    'experiment group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'Waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist']  
}  
df6 = pd.DataFrame(data6)

# %%
# Create the density plot  
plt.figure(figsize=(12, 8))  
sns.kdeplot(df6[df6['experiment group'] == 'FIKA']['GAD7 (SCORE)Pre'], label='FIKA')  
sns.kdeplot(df6[df6['experiment group'] == 'waitlist']['GAD7 (SCORE)Pre'], label='waitlist')  
plt.xlabel('GAD7 (SCORE)Pre')  
plt.ylabel('Density')  
plt.title('Density Map of GAD7 (SCORE)Pre by Experiment Group')  
plt.legend()  
plt.show()

# %%
# Print summary statistics  
print(df6.groupby('experiment group')['GAD7 (SCORE)Pre'].describe())
# Out:
#                   count       mean       std   min   25%   50%   75%   max
# experiment group
# FIKA               29.0  11.137931  5.019420   2.0   6.0  13.0  15.0  20.0
# Waitlist            1.0  11.000000       NaN  11.0  11.0  11.0  11.0  11.0
# waitlist           30.0   8.700000  4.442351   2.0   4.5   9.0  12.0  17.0

# %%
data8 = {  
    'experiment group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'Waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist'],  
    'GAD7 (SCORE)Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 13, 8, 15, 5, 11, 3, 6, 12, 13, 12, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 8, 14, 2, 7, 2, 3, 9, 3, 3, 3, 5, 3, 7, 3]  
}  
df8 = pd.DataFrame(data8)

# %%
# Create the density plot  
plt.figure(figsize=(12, 8))  
sns.kdeplot(df8[df8['experiment group'] == 'FIKA']['GAD7 (SCORE)Post'], label='FIKA')  
sns.kdeplot(df8[df8['experiment group'] == 'waitlist']['GAD7 (SCORE)Post'], label='waitlist')  
plt.xlabel('GAD7 (SCORE)Post')  
plt.ylabel('Density')  
plt.title('Density Map of GAD7 (SCORE)Post by Experiment Group')  
plt.legend()  
plt.show()

# %%
# Print summary statistics  
print(df8.groupby('experiment group')['GAD7 (SCORE)Post'].describe())
# Out:
#                   count      mean       std  min  25%  50%    75%   max
# experiment group
# FIKA               29.0  5.586207  3.775080  0.0  3.0  5.0   7.00  15.0
# Waitlist            1.0  8.000000       NaN  8.0  8.0  8.0   8.00   8.0
# waitlist           30.0  7.733333  4.448427  0.0  5.0  8.0  11.75  16.0

# %%
import scipy.stats as stats

# %%
# Create a Pandas DataFrame from the data  
data9 = {  
    'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'Waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist'],  
    'GAD7_Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 11, 14, 5, 7, 3, 13, 17, 3, 6, 20, 9, 6, 12, 2],  
    'GAD7_Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 13, 8, 15, 5, 11, 3, 6, 12, 13, 12, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 8, 14, 2, 7, 2, 3, 9, 3, 3, 3, 5, 3, 7, 3]  
}  
df9 = pd.DataFrame(data9)

# %%
# Perform Levene's test  
result = stats.levene(df9['GAD7_Pre'][df9['experiment_group'] == 'FIKA'], df9['GAD7_Post'][df9['experiment_group'] == 'FIKA'], center='mean')  
print(result)
# Out:
# LeveneResult(statistic=6.329726053682349, pvalue=0.014767180032619905)

# %%
# Create Q-Q plots  
plt.figure(figsize=(12, 10))

# %%
# Create the Q-Q plot for GAD7_Pre in FIKA group  
stats.probplot(df9['GAD7_Pre'][df9['experiment_group'] == 'FIKA'], dist="norm", plot=plt)  
plt.title('Q-Q Plot for GAD7_Pre (FIKA)')  
plt.xlabel('Theoretical Quantiles')  
plt.ylabel('Sample Quantiles')  
plt.show()

# %%
# Create the Q-Q plot for GAD7_Post in FIKA group  
plt.figure(figsize=(8, 6))  
stats.probplot(df9['GAD7_Post'][df9['experiment_group'] == 'FIKA'], dist="norm", plot=plt)  
plt.title('Q-Q Plot for GAD7_Post (FIKA)')  
plt.xlabel('Theoretical Quantiles')  
plt.ylabel('Sample Quantiles')  
plt.show()

# %%
# Create the Q-Q plot for GAD7_Pre in waitlist group  
plt.figure(figsize=(8, 6))  
stats.probplot(df9['GAD7_Pre'][df9['experiment_group'] == 'waitlist'], dist="norm", plot=plt)  
plt.title('Q-Q Plot for GAD7_Pre (waitlist)')  
plt.xlabel('Theoretical Quantiles')  
plt.ylabel('Sample Quantiles')  
plt.show()

# %%
# Create the Q-Q plot for GAD7_Post in waitlist group  
plt.figure(figsize=(8, 6))  
stats.probplot(df9['GAD7_Post'][df9['experiment_group'] == 'waitlist'], dist="norm", plot=plt)  
plt.title('Q-Q Plot for GAD7_Post (waitlist)')  
plt.xlabel('Theoretical Quantiles')  
plt.ylabel('Sample Quantiles')  
plt.show()

# %%
# Create a dataframe from the image data  
data10 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female'],  
        'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist']}  
df10 = pd.DataFrame(data10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       1 # Create a dataframe from the image data
#       2 data10 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female'],
# ...

# %%
# Create a dataframe from the image data  
data11 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female'],  
        'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist']}  
df11 = pd.DataFrame(data11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 4
#       1 # Create a dataframe from the image data
#       2 data11 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female'],
# ...

# %%
# Create a dataframe from the image data  
data12 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female'],  # <--- one less item  
        'experiment_group': ['FIKA', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'waitlist', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'FIKA', 'waitlist', 'FIKA', 'FIKA', 'waitlist', 'female']}  # <--- add this one  
df12 = pd.DataFrame(data12)  

print(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 4
#       1 # Create a dataframe from the image data
#       2 data12 = {'gender': ['male', 'female', 'male', 'male', 'male', 'male', 'female', 'male', 'male', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'male', 'male', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'male', 'female', 'female', 'male', 'female', 'male', 'male', 'female', 'female'],  # <--- one less item
# ...

# %%
from scipy import stats

# %%
# Perform Levene's test  
W, p_value = stats.levene(df['GAD7 (SCORE)Pre'], df['GAD7 (SCORE)Post'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ia\Desktop\Python\ipynb\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GAD7 (SCORE)Pre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 2
#       1 # Perform Levene's test
# ...

# %%
# Assuming your dataframe is named 'df'  
# Create a new dataframe from the image data  
df_image = pd.DataFrame({  
    'GAD7 (SCORE)Pre': [4, 5, 15, 11, 8, 4, 4, 4, 9, 14, 9, 9, 9, 12, 15, 14, 11, 14, 14, 14, 13, 14, 13, 15, 12, 14, 14, 15, 10, 16, 10, 16, 18, 8, 6, 4, 16, 13, 6, 10, 4, 13, 7, 2, 2, 6, 2, 16, 118, 14, 5, 7, 7, 3, 13, 17, 3, 6, 20, 9, 6, 12, 2],  
    'GAD7 (SCORE)Post': [5, 6, 4, 8, 5, 5, 5, 6, 5, 6, 4, 6, 13, 8, 15, 5, 11, 3, 6, 12, 13, 13, 12, 12, 12, 16, 7, 15, 11, 3, 12, 11, 10, 7, 4, 2, 4, 3, 11, 8, 5, 1, 8, 0, 2, 1, 0, 14, 14, 2, 7, 2, 7, 2, 3, 9, 3, 3, 3, 5, 3, 7, 3]  
})

# %%
# Perform Levene's test  
W, p_value = stats.levene(df_image['GAD7 (SCORE)Pre'], df_image['GAD7 (SCORE)Post'])

# %%
# Calculate the F-statistic  
F = W * (len(df_image['GAD7 (SCORE)Pre']) + len(df_image['GAD7 (SCORE)Post']) - 2) / (len(df_image['GAD7 (SCORE)Pre']) - 1)

# %%
# Print the results  
print("F-statistic:", F)  
print("DF1:", len(df_image['GAD7 (SCORE)Pre']) - 1)  
print("DF2:", len(df_image['GAD7 (SCORE)Pre']) + len(df_image['GAD7 (SCORE)Post']) - 2)  
print("P-value:", p_value)
# Out:
# F-statistic: 3.699938128686731
# DF1: 62
# DF2: 124
# P-value: 0.1762546273909128

# %%
sns.boxplot(x='variable', y='value', data=pd.melt(df_image))  
plt.title('Boxplot of GAD7 (SCORE)Pre and GAD7 (SCORE)Post')  
plt.xlabel('Variable')  
plt.ylabel('Value')  
plt.show()
